# %% [markdown]
# <a href="https://colab.research.google.com/github/NallaniRevathi/GUVI/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ht=13.5
wt=80
bmi=wt/(ht*ht)
bmi
# Out:
# 0.438957475994513
